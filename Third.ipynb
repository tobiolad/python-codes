# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/Farmers Using Digital Agri Loans.csv')

# %%
data.head(10)
# Out:
#                                             FarmerId  ... RepaymentCycles
# 0  4f5f5ddb-6499-4985-a8a1-493576fec5a8-161642962...  ...               1
# 1  4f5f5ddb-6499-4985-a8a1-493576fec5a8-161642962...  ...               1
# 2  6084a229-48be-458f-b6ef-466934093ad5-161599226...  ...               1
# 3  6084a229-48be-458f-b6ef-466934093ad5-161599226...  ...               1
# 4  e421ca3f-f5cf-4270-9371-9da856491d34-161599578...  ...               1
# 5  e421ca3f-f5cf-4270-9371-9da856491d34-161599578...  ...               1
# 6  7ebc3c0f-5219-48e7-939e-a75f3d4324d0-161598024...  ...               1
# 7  7ebc3c0f-5219-48e7-939e-a75f3d4324d0-161598024...  ...               1
# 8  5cd1fa92-176b-4ef2-b891-5fcfedb46978-161599462...  ...               1
# 9  5cd1fa92-176b-4ef2-b891-5fcfedb46978-161599462...  ...               1
#
# [10 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 809 entries, 0 to 808
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FarmerId           809 non-null    object
#  1   State              809 non-null    object
#  2   FarmSize           806 non-null    float64
#  3   LoanType           809 non-null    object
#  4   StartDate          809 non-null    object
#  5   Tenor              809 non-null    int64
#  6   MaturityDate       809 non-null    object
#  7   LoanAmount         809 non-null    int64
#  8   InterestAmount     809 non-null    int64
#  9   TotalIndebtedness  809 non-null    int64
#  10  RepaidAmount       809 non-null    int64
#  11  RepaymentAmount    809 non-null    int64
#  12  RepaymentCycles    809 non-null    int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 82.3+ KB

# %%
data.describe()
# Out:
#          FarmSize  Tenor  ...  RepaymentAmount  RepaymentCycles
# count  806.000000  809.0  ...       809.000000            809.0
# mean     1.116266    6.0  ...     66518.961681              1.0
# std      0.607573    0.0  ...     40353.775213              0.0
# min      0.100000    6.0  ...     21000.000000              1.0
# 25%      0.890000    6.0  ...     21000.000000              1.0
# 50%      1.030000    6.0  ...     90700.000000              1.0
# 75%      1.157500    6.0  ...    102410.000000              1.0
# max      7.970000    6.0  ...    122300.000000              1.0
#
# [8 rows x 8 columns]

# %%
data.tail()
# Out:
#                                               FarmerId  ... RepaymentCycles
# 804  e3555e88-88a5-4dd9-ac1a-80ca02f55169-161801156...  ...               1
# 805  e3079a8c-004f-47fa-98f7-d63ce9a38fa2-161890073...  ...               1
# 806  5bc78a10-ef53-41a3-8f94-7f80e9a3add3-161918514...  ...               1
# 807  a0856bea-58f7-44e7-b09d-3e80426438a7-162149703...  ...               1
# 808  ae5a9b1b-b04e-43f2-a74d-02b8d41abcca-161804396...  ...               1
#
# [5 rows x 13 columns]

# %%
data['State'].unique()
# Out:
# array(['Oyo', 'Kwara', 'Kaduna'], dtype=object)

# %%
data.loc[:,["State","FarmSize"]]
# Out:
#       State  FarmSize
# 0       Oyo      1.01
# 1       Oyo      1.01
# 2       Oyo      4.89
# 3       Oyo      4.89
# 4       Oyo      0.81
# ..      ...       ...
# 804  Kaduna      1.94
# 805  Kaduna      1.39
# 806  Kaduna      0.92
# 807  Kaduna      1.40
# 808  Kaduna      0.59
#
# [809 rows x 2 columns]

# %%
state = data['State']
state
# Out:
# 0         Oyo
# 1         Oyo
# 2         Oyo
# 3         Oyo
# 4         Oyo
#         ...
# 804    Kaduna
# 805    Kaduna
# 806    Kaduna
# 807    Kaduna
# 808    Kaduna
# Name: State, Length: 809, dtype: object

# %%
state.unique()
# Out:
# array(['Oyo', 'Kwara', 'Kaduna'], dtype=object)

# %%
data[data['State'] == 'Oyo']
# Out:
#                                               FarmerId  ... RepaymentCycles
# 0    4f5f5ddb-6499-4985-a8a1-493576fec5a8-161642962...  ...               1
# 1    4f5f5ddb-6499-4985-a8a1-493576fec5a8-161642962...  ...               1
# 2    6084a229-48be-458f-b6ef-466934093ad5-161599226...  ...               1
# 3    6084a229-48be-458f-b6ef-466934093ad5-161599226...  ...               1
# 4    e421ca3f-f5cf-4270-9371-9da856491d34-161599578...  ...               1
# ..                                                 ...  ...             ...
# 699  ea8833d2-f640-4c49-8537-de80533cb64b-161606762...  ...               1
# 700  ea8833d2-f640-4c49-8537-de80533cb64b-161606762...  ...               1
# 701  1f794d4a-ea20-4152-8d07-df43fcda74e8-161855805...  ...               1
# 702  bbb13922-5e4c-412c-a967-9b39a2e400a9-161856661...  ...               1
# 703  bbb13922-5e4c-412c-a967-9b39a2e400a9-161856661...  ...               1
#
# [704 rows x 13 columns]

# %%
data[["FarmSize"]].mean(axis=0)
# Out:
# FarmSize    1.116266
# dtype: float64

# %%
data.head()
# Out:
#                                             FarmerId  ... RepaymentCycles
# 0  4f5f5ddb-6499-4985-a8a1-493576fec5a8-161642962...  ...               1
# 1  4f5f5ddb-6499-4985-a8a1-493576fec5a8-161642962...  ...               1
# 2  6084a229-48be-458f-b6ef-466934093ad5-161599226...  ...               1
# 3  6084a229-48be-458f-b6ef-466934093ad5-161599226...  ...               1
# 4  e421ca3f-f5cf-4270-9371-9da856491d34-161599578...  ...               1
#
# [5 rows x 13 columns]

# %%
data.isnull()
# Out:
#      FarmerId  State  FarmSize  ...  RepaidAmount  RepaymentAmount  RepaymentCycles
# 0       False  False     False  ...         False            False            False
# 1       False  False     False  ...         False            False            False
# 2       False  False     False  ...         False            False            False
# 3       False  False     False  ...         False            False            False
# 4       False  False     False  ...         False            False            False
# ..        ...    ...       ...  ...           ...              ...              ...
# 804     False  False     False  ...         False            False            False
# 805     False  False     False  ...         False            False            False
# 806     False  False     False  ...         False            False            False
# 807     False  False     False  ...         False            False            False
# ...

# %%
oyo_or_kd = (data['State'] == 'Oyo') | (data['State'] == 'Kaduna')

# %%
data[oyo_or_kd]
# Out:
#                                               FarmerId  ... RepaymentCycles
# 0    4f5f5ddb-6499-4985-a8a1-493576fec5a8-161642962...  ...               1
# 1    4f5f5ddb-6499-4985-a8a1-493576fec5a8-161642962...  ...               1
# 2    6084a229-48be-458f-b6ef-466934093ad5-161599226...  ...               1
# 3    6084a229-48be-458f-b6ef-466934093ad5-161599226...  ...               1
# 4    e421ca3f-f5cf-4270-9371-9da856491d34-161599578...  ...               1
# ..                                                 ...  ...             ...
# 804  e3555e88-88a5-4dd9-ac1a-80ca02f55169-161801156...  ...               1
# 805  e3079a8c-004f-47fa-98f7-d63ce9a38fa2-161890073...  ...               1
# 806  5bc78a10-ef53-41a3-8f94-7f80e9a3add3-161918514...  ...               1
# 807  a0856bea-58f7-44e7-b09d-3e80426438a7-162149703...  ...               1
# 808  ae5a9b1b-b04e-43f2-a74d-02b8d41abcca-161804396...  ...               1
#
# [774 rows x 13 columns]

# %%
len(data['State'].unique())
# Out:
# 3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 809 entries, 0 to 808
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FarmerId           809 non-null    object
#  1   State              809 non-null    object
#  2   FarmSize           806 non-null    float64
#  3   LoanType           809 non-null    object
#  4   StartDate          809 non-null    object
#  5   Tenor              809 non-null    int64
#  6   MaturityDate       809 non-null    object
#  7   LoanAmount         809 non-null    int64
#  8   InterestAmount     809 non-null    int64
#  9   TotalIndebtedness  809 non-null    int64
#  10  RepaidAmount       809 non-null    int64
#  11  RepaymentAmount    809 non-null    int64
#  12  RepaymentCycles    809 non-null    int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 82.3+ KB

# %%
data.isnull().sum()
# Out:
# FarmerId             0
# State                0
# FarmSize             3
# LoanType             0
# StartDate            0
# Tenor                0
# MaturityDate         0
# LoanAmount           0
# InterestAmount       0
# TotalIndebtedness    0
# RepaidAmount         0
# RepaymentAmount      0
# RepaymentCycles      0
# dtype: int64

# %%
data.groupby('State')

# %%
data.pivot_table(values='FarmerId', index ='State', aggfunc ='count')
# Out:
#         FarmerId
# State
# Kaduna        70
# Kwara         35
# Oyo          704

# %%
plots = data.pivot_table(values='FarmerId', index ='State', aggfunc ='count')
max_val = plots["FarmerId"].max() + 50
plots.plot(kind='barh', title='Number of Farmers per state', xlim=(0,max_val),legend=True)
